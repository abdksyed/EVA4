# %%
# %reload_ext autoreload

# %%
# %autoreload 2

# %%
from packages.imports import * 
#Importing torch, matplotlib. torch.optim
#Importing custom modules - 
            #data (for train and test data and to display)
            #summary (for summary of Networks)
            #test, train (for training and testing methods)
            #utilis (for diplaying graphs, misclassified images, classwise accuracies)
            #model (for the ResNet18 model)

# %%
train_loader, test_loader = data.loader(128) #Loading CIFAR-10 dataset and splitting into train and test dataloader of batch 128.
data.display(64) #Displaying random 64 images from train dataset.
# Out:
# ...
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
summary.summ(device, 'ResNet18') #To display netwrok archeiture and parameters used
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %%
model = Net.ResNet18().to(device) #Creadting an instance named model, for the ResNet18 and converting to CUDA.
optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum= 0.9, weight_decay= 1e-5) #Defining Stochastic Gradient Descent Optimizer

epochs = 50 #Defining number of epochs

for epoch in range(epochs): #Looping over each epoch to train and test model
  print('EPOCH: ', epoch+1)
  train.train(model, device, train_loader, optimizer, epoch)
  test.test(model, device, test_loader)
# Out:
#   0%|          | 0/391 [00:00<?, ?it/s]
# EPOCH:  1
# Loss=1.0701048374176025 Batch_id=390 Accuracy=47.97: 100%|██████████| 391/391 [00:29<00:00, 13.34it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0082, Accuracy: 6249/10000 (62.49%)
#
# EPOCH:  2
# Loss=0.8606963157653809 Batch_id=390 Accuracy=66.76: 100%|██████████| 391/391 [00:29<00:00, 13.37it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0062, Accuracy: 7251/10000 (72.51%)
#
# EPOCH:  3
# Loss=0.6269711256027222 Batch_id=390 Accuracy=75.04: 100%|██████████| 391/391 [00:29<00:00, 13.37it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0053, Accuracy: 7701/10000 (77.01%)
#
# EPOCH:  4
# Loss=0.6035928130149841 Batch_id=390 Accuracy=79.15: 100%|██████████| 391/391 [00:29<00:00, 13.38it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 7573/10000 (75.73%)
#
# EPOCH:  5
# ...

# %%
utilis.graph() #Getting Training Accuracy, Loss and Testing Accuracy, Loss Graphs

# %%
utilis.testvtrain() #Getting TestvsTrain accuracy graph

# %%
best_model = Net.ResNet18().to(device)
best_model.load_state_dict(torch.load('classifier.pt')) #Loading the best saved model from above training.
best_model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
utilis.mis(best_model, device, test_loader, 36) #Getting 36 random misclassified images from the loaded model
# Out:
# Test set: Average loss: -20.7757, Accuracy: 9166/10000 (91.66%)
#
# (834, 32, 32, 3)

# %%
utilis.class_acc(best_model, device, test_loader) #Getting Class Wise Accuracies for the best model
# Out:
# Accuracy of plane : 93 %
# Accuracy of   car : 96 %
# Accuracy of  bird : 89 %
# Accuracy of   cat : 82 %
# Accuracy of  deer : 91 %
# Accuracy of   dog : 86 %
# Accuracy of  frog : 93 %
# Accuracy of horse : 93 %
# Accuracy of  ship : 94 %
# Accuracy of truck : 96 %

# %%
import packages.utilis as ult

# %%
ult.mis(best_model, device, test_loader, 25)
# Out:
# Test set: Average loss: -20.7757, Accuracy: 9166/10000 (91.66%)
#
# (834, 32, 32, 3)
