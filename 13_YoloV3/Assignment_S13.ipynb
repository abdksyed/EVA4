# %% [markdown]
# <a href="https://colab.research.google.com/github/abksyed/EVA4/blob/master/13_YoloV3/Assignment_S13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
cd gdrive/My Drive/YoloV3
# Out:
# /content/gdrive/My Drive/YoloV3

# %%
ls
# Out:
#  annotation_tool/   __pycache__/   test_batch0.png    Video_2/
#  cfg/               README.md      test.py            Video_2_Out/
#  data/              results.json   ting               vim.exe.stackdump
#  detect.py          results.png    train_batch0.png   weights/
#  models.py          results.txt    train.py
#  out_out/           Rohan_out/    'ubdivisions=1'
#  output/            runs/          utils/

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-07-02 07:14:00.448471: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 7390.19it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 127.75it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 51 --img-size 320 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=51, evolve=False, img_size=[320], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-07-04 09:48:16.199565: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (400 found, 0 missing, 0 empty, 0 duplicate, for 400 images): 100% 400/400 [00:00<00:00, 1146.44it/s]
# Caching images (0.1GB): 100% 400/400 [00:04<00:00, 93.53it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --img-size 320 --output Rohan_out --source 'data/customdata/Rohan_In'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=320, iou_thres=0.6, names='data/customdata/custom.names', output='Rohan_out', save_txt=False, source='data/customdata/Rohan_In', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/1732 data/customdata/Rohan_In/image-001.jpg: 192x320 1 Guitars, Done. (0.015s)
# image 2/1732 data/customdata/Rohan_In/image-002.jpg: 192x320 1 Guitars, Done. (0.013s)
# image 3/1732 data/customdata/Rohan_In/image-003.jpg: 192x320 1 Guitars, Done. (0.012s)
# image 4/1732 data/customdata/Rohan_In/image-004.jpg: 192x320 1 Guitars, Done. (0.015s)
# image 5/1732 data/customdata/Rohan_In/image-005.jpg: 192x320 1 Guitars, Done. (0.013s)
# ...

# %%
Image(filename='Rohan_out/image-125.jpg', width=192)

# %%
Image(filename='Rohan_out/image-130.jpg', width=192)

# %%
Image(filename='Rohan_out/image-250.jpg', width=192)

# %%
Image(filename='Rohan_out/image-688.jpg', width=192)
